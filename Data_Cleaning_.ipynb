# %%
Data Cleaning

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d9cee07d-6822-4ad0-bd4b-f8f06a057551" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d9cee07d-6822-4ad0-bd4b-f8f06a057551">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import re

# %%
pd.read_excel('Datafile_2.xlsx')
# Out:
#         Id                                                Url  \
# 0        1  https://housing.com/in/buy/resale/page/2760130...
# 1        2  https://housing.com/in/buy/resale/page/2757498...
# 2        3  https://housing.com/in/buy/resale/page/2753188...
# 3        4  https://housing.com/in/buy/resale/page/2747709...
# 4        5  https://housing.com/in/buy/resale/page/2750468...
# ...    ...                                                ...
# 9441  9442  https://housing.com/in/buy/resale/page/1015695...
# 9442  9443  https://housing.com/in/buy/resale/page/1085796...
# 9443  9444  https://housing.com/in/buy/resale/page/1085438...
# 9444  9445  https://housing.com/in/buy/resale/page/968599-...
# 9445  9446  https://housing.com/in/buy/resale/page/709238-...
#
#                 Title                             Breadcrumb  \
# 0     2 BHK Apartment  Home | Thane | Thane West | 2760130 |
# 1     2 BHK Apartment  Home | Thane | Thane West | 2757498 |
# ...

# %%
df = pd.read_excel('Datafile_2.xlsx')
df.head()
# Out:
#    Id                                                Url            Title  \
# 0   1  https://housing.com/in/buy/resale/page/2760130...  2 BHK Apartment
# 1   2  https://housing.com/in/buy/resale/page/2757498...  2 BHK Apartment
# 2   3  https://housing.com/in/buy/resale/page/2753188...  2 BHK Apartment
# 3   4  https://housing.com/in/buy/resale/page/2747709...  2 BHK Apartment
# 4   5  https://housing.com/in/buy/resale/page/2750468...  1 BHK Apartment
#
#                               Breadcrumb  \
# 0  Home | Thane | Thane West | 2760130 |
# 1  Home | Thane | Thane West | 2757498 |
# 2  Home | Thane | Thane West | 2753188 |
# 3   Home | Thane | Shilphata | 2747709 |
# 4  Home | Thane | Thane West | 2750468 |
#
#                                              Address   City     PossesionDate  \
# 0                 Swastik Regalia, Thane West, Thane  thane  Ready to move in
# 1                           Amara, Thane West, Thane  thane        June, 2019
# ...

# %%
df.isnull().sum()
# Out:
# Id                        0
# Url                       0
# Title                     0
# Breadcrumb                0
# Address                   0
# City                      0
# PossesionDate             9
# builtuparea               0
# CarpetArea             1923
# Amenities              1659
# Latitude                  0
# Longitude                 0
# Building name-1        7527
# AgeOfProperty          2588
# Buildingname           7354
# Bedroom                   0
# bathroom               1363
# parking                7117
# price                     0
# Built up area Rate        0
# Facing                 1836
# Floors                    0
# Images                 1441
# dtype: int64

# %%
df = df.dropna()

# %%
df = df.drop_duplicates()

# %%
df['Address'] = df['Address'].apply(lambda x: re.sub(r'[^a-zA-Z0-9\s,]', '', str(x)))
df['Breadcrumb'] = df['Breadcrumb'].apply(lambda x: str(x).zfill(5))

# %%
print(df.head())
print(df.info())
# Out:
# Empty DataFrame
# Columns: [Id, Url, Title, Breadcrumb, Address, City, PossesionDate, builtuparea, CarpetArea, Amenities, Latitude, Longitude, Building name-1, AgeOfProperty, Buildingname, Bedroom, bathroom, parking, price, Built up area Rate , Facing, Floors, Images]
# Index: []
#
# [0 rows x 23 columns]
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   0 non-null      int64
#  1   Url                  0 non-null      object
#  2   Title                0 non-null      object
#  3   Breadcrumb           0 non-null      object
#  4   Address              0 non-null      object
#  5   City                 0 non-null      object
#  6   PossesionDate        0 non-null      object
#  7   builtuparea          0 non-null      object
#  8   CarpetArea           0 non-null      object
# ...

# %%
if 'City' in df.columns:
  df['City'] = df['City'].apply(clean_city)

# %%
if 'Sales' in df.columns:
  df['Sales'] = df['Sales'].fillna(df['Sales'].mean())

# %%
if 'ProductName' in df.columns:
    df['ProductName'] = df['ProductName'].apply(lambda x: re.sub(r'[^\w\s]', '', str(x)))

# %%
if 'Quantity' in df.columns:
  df = df[df['Quantity'] >= 0]

# %%
df['Breadcrumb'] = df['Breadcrumb'].apply(lambda x: str(x).zfill(5))

# %%
for col in df.columns:
    print(f"Column '{col}': {df[col].dtype}")
# Out:
# Column 'Id': int64
# Column 'Url': object
# Column 'Title': object
# Column 'Breadcrumb': object
# Column 'Address': object
# Column 'City': object
# Column 'PossesionDate': object
# Column 'builtuparea': object
# Column 'CarpetArea': object
# Column 'Amenities': object
# Column 'Latitude': float64
# Column 'Longitude': float64
# Column 'Building name-1': object
# Column 'AgeOfProperty': object
# Column 'Buildingname': object
# Column 'Bedroom': int64
# Column 'bathroom': float64
# Column 'parking': float64
# Column 'price': object
# Column 'Built up area Rate ': object
# Column 'Facing': object
# Column 'Floors': object
# Column 'Images': object
